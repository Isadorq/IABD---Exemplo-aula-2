# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('monitoramento_tempo.csv')

# %%
df['data'] = pd.to_datetime(df['data'])

# %%
data_inicio = '2016-05-27'
data_fim = '2016-08-01'

df_filtrado_intervalo = df[(df['data'] >= data_inicio) & (df['data'] <= data_fim)]

# %%
df_ano = df[df['data'].dt.year == 2016]

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2, ncols=1, figsize=(12, 10), sharex=True)

ax1.plot(df_filtrado_intervalo['data'], df_filtrado_intervalo['temperatura'], color='b', marker='o')
ax1.set_title('Temperatura de Maio 2016 a Agosto 2016')
ax1.set_ylabel('Temperatura (°C)')
ax1.grid(True)

ax2.plot(df_mensal.index, df_mensal.values, color='r', marker='o')
ax2.set_title('Temperatura Média Mensal de 2016')
ax2.set_xlabel('Mês')
ax2.set_ylabel('Temperatura Média (°C)')
ax2.set_xticks(df_mensal.index)
ax2.set_xticklabels(['Jan', 'Fev', 'Mar', 'Abr', 'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez'])
ax2.grid(True)

plt.tight_layout()

plt.show()
